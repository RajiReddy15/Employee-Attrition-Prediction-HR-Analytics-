# %% [markdown]
# # Importing Important libraries

# %%
import pandas as pd
import numpy as np
import mysql.connector
## pip install mysql-connector-python

# %% [markdown]
# # Importing data from mysql workbench

# %%
mybd=mysql.connector.connect(
    host="localhost",
    user="root",
    password="root123",
    database="hr(attrition)"
)
mycursor=mybd.cursor()
mycursor.execute("SELECT * FROM employeeattrition")
data=mycursor.fetchall()
columns = [desc[0] for desc in mycursor.description]

# %% [markdown]
# # 2 Method
#
# By default we can import data by using pandas library
#
# source code:
#
#     data=pd.read_csv("Path")
#
#     data

# %%
df=pd.DataFrame(data,columns=columns)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Relation between different columns vs attrition

# %% [markdown]
# | Column Name              | Type        | Category  | Notes / Action                         |
# | ------------------------ | ----------- | --------- | -------------------------------------- |
# | Age                      | Numeric     | Main      | Important for model                    |
# | Attrition                | Target      | Main      | Target variable                        |
# | BusinessTravel           | Categorical | Main      | High relation with attrition           |
# | DailyRate                | Numeric     | Secondary | Low/no relation → can drop             |
# | Department               | Categorical | Main      | Include as main column                 |
# | DistanceFromHome         | Numeric     | Main      | High distance → higher attrition       |
# | Education                | Numeric     | Secondary | Optional, low relation → can drop      |
# | EducationField           | Categorical | Secondary | Optional → can drop                    |
# | EmployeeCount            | Numeric     | Unrelated | Drop                                   |
# | EmployeeNumber           | Numeric     | Unrelated | Drop, only ID                          |
# | EnvironmentSatisfaction  | Numeric     | Main      | Important predictor                    |
# | Gender                   | Categorical | Main      | Can include or ignore based on project |
# | HourlyRate               | Numeric     | Secondary | Low relation → can drop                |
# | JobInvolvement           | Numeric     | Secondary | Optional → can drop                    |
# | JobLevel                 | Numeric     | Main      | Include as main column                 |
# | JobRole                  | Categorical | Main      | Important predictor                    |
# | JobSatisfaction          | Numeric     | Main      | Important predictor                    |
# | MaritalStatus            | Categorical | Secondary | Optional → can drop                    |
# | MonthlyIncome            | Numeric     | Main      | High relation with attrition           |
# | MonthlyRate              | Numeric     | Secondary | Optional → can drop                    |
# | NumCompaniesWorked       | Numeric     | Main      | Has impact on attrition                |
# | Over18                   | Categorical | Unrelated | Drop, constant value                   |
# | OverTime                 | Categorical | Main      | Strong predictor                       |
# | PercentSalaryHike        | Numeric     | Main      | High relation                          |
# | PerformanceRating        | Numeric     | Secondary | Optional → can drop                    |
# | RelationshipSatisfaction | Numeric     | Main      | Include as main column                 |
# | StandardHours            | Numeric     | Unrelated | Drop, constant                         |
# | StockOptionLevel         | Numeric     | Secondary | Optional → can drop                    |
# | TotalWorkingYears        | Numeric     | Main      | Important predictor                    |
# | TrainingTimesLastYear    | Numeric     | Main      | Include as main column                 |
# | WorkLifeBalance          | Numeric     | Main      | Important predictor                    |
# | YearsAtCompany           | Numeric     | Main      | Important predictor                    |
# | YearsInCurrentRole       | Numeric     | Main      | Important predictor                    |
# | YearsSinceLastPromotion  | Numeric     | Main      | Important predictor                    |
# | YearsWithCurrManager     | Numeric     | Main      | Important predictor                    |

# %% [markdown]
# # Droping unnecessary columns and secondary columns

# %%
# Drop unnecessary columns
df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis=1, inplace=True)
secondary_columns = [
    'DailyRate',
    'Education',
    'EducationField',
    'HourlyRate',
    'JobInvolvement',
    'MaritalStatus',
    'MonthlyRate',
    'PerformanceRating',
    'StockOptionLevel'
]

# Drop secondary columns
df = df.drop(columns=secondary_columns)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EnvironmentSatisfaction', 'Gender', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'RelationshipSatisfaction', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Saving the data into new table in mysql workbench

# %%
from sqlalchemy import create_engine
# MySQL connection credentials
username = "root"
password = "root123"
host = "localhost"
port = 3306
database = "hr(attrition)"  # your database name

# Correct SQLAlchemy engine (no backticks in URL)
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Insert data into MySQL table
df.to_sql('employeeattrition_main', con=engine, if_exists='replace', method='multi', index=False,chunksize=1000 )
# Out:
# 1470

# %%
# retriving data from the new table to verify
df_new = pd.read_sql("SELECT * FROM employeeattrition_main", con=engine)
df_new.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    EnvironmentSatisfaction  Gender  JobLevel                JobRole  \
# 0                        2  Female         2        Sales Executive
# 1                        3    Male         2     Research Scientist
# 2                        4    Male         1  Laboratory Technician
# 3                        4  Female         1     Research Scientist
# 4                        1    Male         1  Laboratory Technician
#
#    JobSatisfaction  ...  OverTime  PercentSalaryHike RelationshipSatisfaction  \
# ...

# %% [markdown]
# # checking if new table have the same data

# %%
df==df_new
# Out:
#        Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     True       True            True        True              True
# 1     True       True            True        True              True
# 2     True       True            True        True              True
# 3     True       True            True        True              True
# 4     True       True            True        True              True
# ...    ...        ...             ...         ...               ...
# 1465  True       True            True        True              True
# 1466  True       True            True        True              True
# 1467  True       True            True        True              True
# 1468  True       True            True        True              True
# 1469  True       True            True        True              True
#
#       EnvironmentSatisfaction  Gender  JobLevel  JobRole  JobSatisfaction  \
# 0                        True    True      True     True             True
# ...
